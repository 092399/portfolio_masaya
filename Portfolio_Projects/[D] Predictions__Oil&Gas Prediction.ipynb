# %%
# Basic libraries to manipulate data
import numpy as np #Numpy for numerical computations
import pandas as pd #Pandas for data manipulation
import matplotlib.pyplot as plt #Matplotlib for data visualization
import matplotlib.ticker as ticker
import seaborn as sns #Seaborn for data visualization
import plotly.express as px
from scipy import stats
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import export_graphviz
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.tree import plot_tree
from sklearn.metrics import r2_score
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import acf


#Ignore warnings
import warnings
warnings.filterwarnings("ignore") # This is to ignore any warnings that might pop up during execution

# %%
# Specify the path to the datasets
data_path = "./data/"

# Specify the filenames of the datasets
Metadata_filename = "Metadata.xlsx"
Production_filename = "Production Data.xlsx"

# Read the Excel files
metadata_df = pd.read_excel(data_path + Metadata_filename)
production_df = pd.read_excel(data_path + Production_filename)

# Create working copies of the dataframes for analysis
metadata_df_copy = metadata_df.copy()
production_df_copy = production_df.copy()

# %%
# Count missing values in each column for Production DataFrame
production_missing_values = production_df_copy.isnull().sum()
print("\nMissing values in Production DataFrame:")
print(production_missing_values)
# Out:
# Missing values in Production DataFrame:
# WellID                                        0
# CompletionID                                  0
# API_UWI                                       0
# WellName                                      0
# WellboreId                                    0
# ProducingMonth                                0
# TotalProdMonths                               0
# TotalCompletionMonths                         0
# ProducingDays                                 0
# Prod_BOE                                      0
# Prod_MCFE                                     0
# LiquidsProd_BBL                               0
# GasProd_MCF                                   0
# WaterProd_BBL                                 0
# RepGasProd_MCF                                0
# CDProd_BOEPerDAY                              0
# CDProd_MCFEPerDAY                             0
# CDLiquids_BBLPerDAY                           0
# CDGas_MCFPerDAY                               0
# CDWater_BBLPerDAY                             0
# CDRepGas_MCFPerDAY                            0
# PDProd_BOEPerDAY                              0
# PDProd_MCFEPerDAY                             0
# PDLiquids_BBLPerDAY                           0
# PDGas_MCFPerDAY                               0
# PDWater_BBLPerDAY                             0
# PDRepGas_MCFPerDAY                            0
# CumProd_BOE                                   0
# CumProd_MCFE                                  0
# CumLiquids_BBL                                0
# CumGas_MCF                                    0
# CumWater_BBL                                  0
# CumRepGas_MCF                                 0
# ProductionReportedMethod                      0
# ProducingOperator                          1383
# InjectionGas_MCF                         106835
# InjectionSolvent_BBL                     106835
# InjectionSteam_BBL                       106835
# InjectionWater_BBL                       106835
# InjectionOther_BBL                       106835
# CalendarDayInjectionWater_BBLPerDAY      106835
# CalendarDayInjectionSteam_BBLPerDAY      106835
# CalendarDayInjectionSolvent_BBLPerDAY    106835
# CalendarDayInjectionGas_MCFPerDAY        106835
# CalendarDayInjectionOther_BBLPerDAY      106835
# ENVProdID                                     0
# dtype: int64

# %%
columns_to_retain = ['API_UWI', 'WellName', 'ProducingMonth', 'TotalProdMonths', 'Prod_BOE', 
                     'Prod_MCFE', 'LiquidsProd_BBL', 'GasProd_MCF', 'WaterProd_BBL', 
                     'RepGasProd_MCF', 'ProductionReportedMethod', 'ProducingOperator', 'ENVProdID']

# Retain only the specified columns
production_df = production_df[columns_to_retain]

# %%
# Set pandas display option to show all rows
pd.set_option('display.max_rows', None)

metadata_missing_values = metadata_df.isnull().sum()

# Print missing values in Metadata DataFrame
print("Missing values in Metadata DataFrame:")
print(metadata_missing_values)

# Reset pandas display option to default
pd.set_option('display.max_rows', 50) 
pd.set_option('display.max_columns', 50)
# Out:
# Missing values in Metadata DataFrame:
# API_UWI                                            0
# Unformatted_API_UWI                                0
# API_UWI_12                                         0
# Unformatted_API_UWI_12                             0
# API_UWI_14                                         0
# Unformatted_API_UWI_14                             0
# WellID                                             0
# CompletionID                                       0
# WellPadID                                          0
# WellPadDirection                                  17
# ENVWellGrouping                                 2863
# CompletionNumber                                  18
# WellName                                           0
# Country                                            0
# StateProvince                                      0
# County                                             0
# Lease                                              0
# LeaseName                                          0
# ENVOperator                                        0
# RawOperator                                        0
# InitialOperator                                    0
# ENVTicker                                          0
# ENV_Peer_Group                                     0
# ENV_Stock_Exchange                               646
# ENVWellServiceProvider                           137
# ENVProdWellType                                    0
# StateWellType                                      0
# ENVWellType                                        0
# ENVProducingMethod                              1246
# ENVRegion                                          0
# ENVBasin                                           0
# ENVPlay                                            0
# ENVSubPlay                                         0
# ENVInterval                                        0
# ENVIntervalSource                                  0
# ENVSpacingAssumption                             362
# ENVWellStatus                                      0
# ENVWellboreStatus                                  0
# OnConfidential                                  2863
# OffConfidentialDate                             2863
# Trajectory                                         0
# ENVWellboreType                                    0
# Formation                                          2
# FirstProdDate                                      0
# Latitude                                           0
# Longitude                                          0
# Latitude_BH                                        0
# Longitude_BH                                       0
# TVD_FT                                             6
# MD_FT                                            103
# District                                        2863
# Field                                              0
# Survey                                          2863
# Block                                           2863
# Abstract                                        2863
# Platform                                        2863
# Section                                            0
# Township                                           0
# Range                                              0
# Section_Township_Range                             0
# Unit_Name                                        104
# WellNumber                                         0
# SurfaceLatitudeLongitudeSource                     0
# PlugDate                                        2861
# PlugbackMeasuredDepth_FT                        1094
# PlugbackTrueVerticalDepth_FT                    1853
# AvgBreakdownPressure_PSI                        2863
# AvgClusterSpacingPerStage_FT                    2863
# AvgClusterSpacing_FT                            2863
# AvgFracGradient_PSIPerFT                        2863
# AvgISIP_PSI                                     2863
# AvgMillTime_Min                                 2863
# AvgPortSleeveOpeningPressure_PSI                2863
# AvgShotsPerCluster                              2863
# AvgShotsPerFt                                   2863
# AvgTreatmentPressure_PSI                        2863
# AvgTreatmentRate_BBLPerMin                      2863
# ClustersPer1,000Ft                              2863
# ClustersPerStage                                2863
# ShotsPer1,000Ft                                 2863
# ShotsPerStage                                   2863
# TotalShots                                      2863
# AvgFluidPerCluster_BBL                          2863
# AvgFluidPerShot_BBL                             2863
# AvgFluidPerStage_BBL                            1255
# FracRigOnsiteDate                               2863
# FracRigReleaseDate                              2863
# AvgProppantPerCluster_LBS                       2863
# AvgProppantPerShot_LBS                          2863
# AvgProppantPerStage_LBS                         1043
# StimulatedStages                                2863
# TotalClusters                                   2863
# Vintage                                            0
# FirstProdQuarter                                   0
# FirstProdMonth                                     0
# ENVElevationKB_FT                                745
# ENVElevationKBSource                             745
# ENVElevationGL_FT                                745
# ENVElevationGLSource                             745
# ElevationKB_FT                                     0
# ElevationGL_FT                                     0
# CoordinateSource                                   6
# PermitApprovedDate                                 0
# PermitSubmittedDate                             2862
# SpudDate                                           6
# DrillingEndDate                                 1273
# RigReleaseDate                                    38
# CompletionDate                                    18
# FirstRigDay                                      127
# ENVCompInsertedDate                              120
# StateFileNumber                                 2863
# ENVFracJobType                                   245
# ENVFluidType                                     246
# CompletionTime_DAYS                              244
# CompletionDesign                                2863
# PermitToSpud_DAYS                                  3
# SpudToRigRelease_DAYS                             32
# SpudToCompletion_DAYS                             20
# SpudToSales_DAYS                                   2
# SoakTime_DAYS                                   1180
# NumberOfStrings                                  889
# UpperPerf_FT                                     876
# LowerPerf_FT                                     876
# PerfInterval_FT                                   21
# LateralLength_FT                                   0
# FracStages                                      1635
# AverageStageSpacing_FT                          1635
# ENVProppantBrand                                2186
# ProppantLoading_LBSPerGAL                        223
# ENVProppantType                                  198
# ProppantIntensity_LBSPerFT                       186
# Proppant_LBS                                     170
# TotalWaterPumped_GAL                             183
# WaterIntensity_GALPerFT                          199
# TotalFluidPumped_BBL                             186
# FluidIntensity_BBLPerFT                          202
# AcidVolume_BBL                                  1086
# Bottom_Hole_Temp_DEGF                           2851
# Biocide_LBS                                      965
# Breaker_LBS                                     2322
# Buffer_LBS                                      2744
# ClayControl_LBS                                 2533
# CrossLinker_LBS                                 2756
# FrictionReducer_LBS                              840
# GellingAgent_LBS                                2497
# IronControl_LBS                                 1940
# ScaleInhibitor_LBS                              2221
# Surfactant_LBS                                  1772
# Energizer_LBS                                   2863
# Diverter_LBS                                    2356
# TestDate                                        1105
# ChokeSize_64IN                                  1470
# TestRate_BOEPerDAY                              1105
# TestRate_BOEPerDAYPer1000FT                     1105
# TestRate_MCFEPerDAY                             1105
# OilTestRate_BBLPerDAY                           1107
# OilTestRate_BBLPerDAYPer1000FT                  1107
# GasTestRate_MCFPerDAY                           1115
# GasTestRate_MCFPerDAYPer1000FT                  1115
# WaterTestRate_BBLPerDAY                         1108
# WaterTestRate_BBLPerDAYPer1000Ft                1108
# WaterDepth                                      2863
# TestWHLiquids_PCT                               1107
# CasingPressure_PSI                              1342
# FlowingTubingPressure_PSI                       2358
# ShutInPressure_PSI                              2863
# OilProdPriorTest_BBL                            2863
# OilTestMethodName                               1246
# OilGravity_API                                  2101
# GasGravity_SG                                   2863
# First3MonthProd_BOE                              119
# First3MonthProd_BOEPer1000FT                     119
# First3MonthGas_MCF                               119
# First3MonthGas_MCFPer1000FT                      119
# First3MonthProd_MCFE                             119
# First3MonthProd_MCFEPer1000FT                    119
# First3MonthOil_BBL                               119
# First3MonthOil_BBLPer1000FT                      119
# First3MonthWater_BBL                             119
# First6MonthProd_BOE                              214
# First6MonthProd_BOEPer1000FT                     214
# First6MonthGas_MCF                               214
# First6MonthGas_MCFPer1000FT                      214
# First6MonthProd_MCFE                             214
# First6MonthProd_MCFEPer1000FT                    214
# First6MonthOil_BBL                               214
# First6MonthOil_BBLPer1000FT                      214
# First6MonthWater_BBL                             214
# First9MonthProd_BOE                              305
# First9MonthProd_BOEPer1000FT                     305
# First9MonthGas_MCF                               305
# First9MonthGas_MCFPer1000FT                      305
# First9MonthProd_MCFE                             305
# First9MonthProd_MCFEPer1000FT                    305
# First9MonthOil_BBL                               305
# First9MonthOil_BBLPer1000FT                      305
# First9MonthWater_BBL                             305
# First12MonthProd_BOE                             415
# First12MonthProd_BOEPer1000FT                    415
# First12MonthGas_MCF                              415
# First12MonthGas_MCFPer1000FT                     415
# First12MonthProd_MCFE                            415
# First12MonthProd_MCFEPer1000FT                   415
# First12MonthOil_BBL                              415
# First12MonthOil_BBLPer1000FT                     415
# First12MonthWater_BBL                            415
# First36MonthProd_BOE                            1484
# First36MonthProd_BOEPer1000FT                   1484
# First36MonthGas_MCF                             1484
# First36MonthGas_MCFPer1000FT                    1484
# First36MonthProd_MCFE                           1484
# First36MonthProd_MCFEPer1000FT                  1484
# First36MonthOil_BBL                             1484
# First36MonthOil_BBLPer1000FT                    1484
# First36MonthWater_BBL                           1484
# First36MonthWaterProductionBBLPer1000Ft         1484
# PeakProductionDate                                34
# MonthsToPeakProduction                            34
# PeakProd_BOE                                      34
# PeakProd_BOEPer1000FT                             34
# PeakGas_MCF                                       34
# PeakGas_MCFPer1000FT                              34
# PeakProd_MCFE                                     34
# PeakProd_MCFEPer1000FT                            34
# PeakOil_BBL                                       34
# PeakOil_BBLPer1000FT                              34
# PeakWater_BBL                                     34
# CumProd_BOE                                       34
# CumProd_BOEPer1000FT                              34
# CumGas_MCF                                        34
# CumGas_MCFPer1000FT                               34
# CumProd_MCFE                                      34
# CumProd_MCFEPer1000FT                             34
# CumOil_BBL                                        34
# CumOil_BBLPer1000FT                               34
# CumWater_BBL                                      34
# TotalProducingMonths                              34
# LastProducingMonth                                34
# LastMonthLiquidsProduction_BBL                    34
# LastMonthGasProduction_MCF                        34
# LastMonthWaterProduction_BBL                      34
# Last12MonthBOEProduction                          34
# Last12MonthGasProduction_MCF                      34
# Last12MonthOilProduction_BBL                      34
# Last12MonthWaterProduction_BBL                    34
# WHLiquids_PCT                                     34
# GOR_ScfPerBbl                                     34
# CumulativeSOR                                   2863
# Last3MonthISOR                                  2863
# Tortuosity                                        27
# ToeAngle_DEG                                      51
# AzimuthFromGridNorth_DEG                          51
# ParentChildAnyZone                                51
# ParentChildSameZone                               51
# BoundedAnyZone                                    51
# BoundedSameZone                                   51
# Bounded100dVZoneCurrent                           51
# BoundedAnyZoneInitial                             51
# BoundedSameZoneInitial                            51
# Bounded100dVZoneInitial                           51
# CoCompletion                                      51
# WellDensityAnyZone                                86
# WellDensitySameZone                              390
# WellsPerSectionAnyZone                            51
# WellsPerSectionSameZone                           51
# ImpliedWellSpacingSameZone_FT                    390
# AvgHzDistAtDrillTimeSameZone_FT                  610
# AvgVtDistAtDrillTimeSameZone_FT                  610
# ClosestHzDistAtDrillTimeSameZone_FT              610
# ClosestVtDistAtDrillTimeSameZone_FT              610
# AvgHzDistAtDrillTimeAnyZone_FT                   178
# AvgVtDistAtDrillTimeAnyZone_FT                   178
# ClosestHzDistAtDrillTimeAnyZone_FT               178
# ClosestVtDistAtDrillTimeAnyZone_FT               178
# ClosestHzDistAtDrillTime100dVZone_FT             444
# ClosestVtDistAtDrillTime100dVZone_FT             561
# AvgHzDistAtDrillTime100dVZone_FT                 444
# AvgVtDistAtDrillTime100dVZone_FT                 561
# AvgHzDistSameZone_FT                             390
# AvgVtDistSameZone_FT                             390
# ClosestHzDistSameZone_FT                         390
# ClosestVtDistSameZone_FT                         390
# AvgHzDistAnyZone_FT                               86
# AvgVtDistAnyZone_FT                               86
# ClosestHzDistAnyZone_FT                           86
# ClosestVtDistAnyZone_FT                           86
# ClosestHzDist100dVZone_FT                        236
# ClosestVtDist100dVZone_FT                        282
# AvgHzDist100dVZone_FT                            236
# AvgVtDist100dVZone_FT                            282
# RoyaltyRateOil_PCT                                57
# RoyaltyRateGas_PCT                                57
# RoyaltyRateNGL_PCT                                57
# OilDifferential_PCT                               57
# OilDifferential_USDPerBBL                         57
# NGLDifferential_PCT                               57
# NGLDifferential_USDPerBBL                         57
# GasDifferential_PCT                               57
# GasDifferential_USDPerMCF                         57
# PostProcessingGrossUp_PCT                        178
# TotalOpex_USDPerBOE                              178
# VariableOpex_USDPerBOE                            57
# TransportationCost_USDPerBOE                      57
# FixedOpex_USDPerWELLPerMONTH                      57
# ProcessingFee_USDPerMCF                           57
# GAndA_USDPerBOE                                   34
# OilSeveranceTax_PCT                               57
# NGLSeveranceTax_PCT                               57
# GasSeveranceTax_PCT                               57
# DrillingCost_USDMM                                34
# CompletionCost_USDMM                              34
# TieInCost_USDMM                                   34
# TotalWellCost_USDMM                               34
# DrillingCostHistorical_USDMM                     296
# CompletionCostHistorical_USDMM                   296
# TieInCostHistorical_USDMM                        296
# TotalWellCostHistorical_USDMM                    296
# GasShrink_PCT                                     57
# NGLYield_BBLPerMMCF                               57
# GenericDrainage_AC                               178
# NPVPerWELLAt50And200_USDMM                       178
# NPVPerWELLAt55And300_USDMM                       178
# NPVPerWELLAt60And300_USDMM                       178
# NPVPerWELLAt60And350_USDMM                       178
# NPVPerWELLAt50And200Historical_USDMM             411
# NPVPerWELLAt55And300Historical_USDMM             411
# NPVPerWELLAt60And300Historical_USDMM             411
# NPVPerWELLAt60And350Historical_USDMM             411
# NPVPerSectionAnyZone_USDMM                       190
# NPVPerSectionSameZone_USDMM                      190
# HistoricalNPVPerSectionAnyZone                   423
# HistoricalNPVPerSectionSameZone                  423
# GenericAcreValue10Yr_USD                         179
# IRRPerWELLAt50And200_USDMM                       178
# IRRPerWELLAt55And300_USDMM                       178
# IRRPerWELLAt60And300_USDMM                       178
# IRRPerWELLAt60And350_USDMM                       178
# IRRPerWELLAt50And200Historical_USDMM             411
# IRRPerWELLAt55And300Historical_USDMM             411
# IRRPerWELLAt60And300Historical_USDMM             411
# IRRPerWELLAt60And350Historical_USDMM             411
# PayoutPeriod_MONTHS                              178
# FindingAndDevelopment_USDPerBOE                  178
# NetbackPerWELLAt50And200_USDMM                   178
# NetbackPerWELLAt55And300_USDMM                   178
# NetbackPerWELLAt60And300_USDMM                   178
# NetbackPerWELLAt60And350_USDMM                   178
# RecycleRatioPerWELLAt50And200_USDMM              178
# RecycleRatioPerWELLAt55And300_USDMM              178
# RecycleRatioPerWELLAt60And300_USDMM              178
# RecycleRatioPerWELLAt60And350_USDMM              178
# CapitalEfficiency_USDPerBOEPerDAY                178
# EURWH_MBOE                                       155
# OilEURWH_MBBL                                    155
# GasEURWH_BCF                                     155
# EURWH_MBOE_360                                   155
# EURWH_BCFE_360                                   155
# EURWH_MBBL_360                                   155
# EURWH_BCF_360                                    155
# EURWH_MBOE_180                                   155
# EURWH_MBOE_120                                   155
# EURWH_MBOE_60                                    155
# ForecastWHLiquids_PCT                            155
# EURPP_MBOE                                       178
# EURPerSectionAnyZone_MBOE                        167
# EURPerSectionSameZone_MBOE                       167
# EURPerSectionAnyZone_MBBL                        167
# EURPerSectionSameZone_MBBL                       167
# OilEURPP_PCT                                     178
# NGLEURPP_PCT                                     178
# GasEURPP_PCT                                     178
# BE15To1WTINYMEX_USDPerBBL                        178
# BE20To1WTINYMEX_USDPerBBL                        178
# BE25To1WTINYMEX_USDPerBBL                        178
# BE15To1WTINYMEXHistorical_USDPerBBL              411
# BE20To1WTINYMEXHistorical_USDPerBBL              411
# BE25To1WTINYMEXHistorical_USDPerBBL              411
# BE15To1WTIYMEX_USDPerMcf                         178
# BE20To1WTINYMEX_USDPerMcf                        178
# BE25To1WTINYMEX_USDPerMcf                        178
# BE15To1WTINYMEXHistorical_USDPerMcf              411
# BE20To1WTINYMEXHistorical_USDPerMcf              411
# BE25To1HHNYMEXHistorical_USDPerMcf               411
# TopOfZone_FT                                      37
# BottomOfZone_FT                                   37
# SubseaTopDepth_FT                                 37
# SubseaBaseDepth_FT                                37
# Isopach_FT                                        37
# GammaRay_API                                      37
# BulkDensity_GPerCC                                37
# Resistivity_OHMSM                                 37
# DensityPorosity_PCT                               37
# EffectivePorosity_PCT                             37
# ClayVolume_PCT                                    37
# NonClayVolume_PCT                                 37
# WaterSaturation_PCT                               37
# PhiH_FT                                           37
# HCPV_PCT                                          37
# HeightOfHCPV_FT                                   37
# TotalOrganicCarbon_WTPCT                          37
# GasInitialRate                                   167
# GasBFactor                                       167
# GasInitialDecline                                167
# GasTerminalDecline                               167
# GasDailyPeakEURRatio_MCFtoMCFPerDay              168
# GasGroupLevel                                   2312
# GasGroupID                                      2312
# GasFirstTC_MONTH                                 168
# GasRefCompletionUsage                             39
# OilInitialRate                                   166
# OilBFactor                                       166
# OilInitialDecline                                166
# OilTerminalDecline                               166
# OilDailyPeakEURRatio_BBLPerDaytoMBBL             167
# OilGroupLevel                                   2359
# OilGroupID                                      2359
# OilFirstTC_MONTH                                 167
# OilRefCompletionUsage                             39
# ClosestAnyProdMonthDiff                           34
# AverageAnyProdMonthDiff                           34
# ClosestSameProdMonthDiff                          34
# AverageSameProdMonthDiff                          34
# Closest100dVProdMonthDiff                         34
# Average100dVProdMonthDiff                         34
# ENVSpacingClass_AnyZone                           51
# ENVSpacingClass_SameZone                          51
# ENVSpacingClass_Within100                         51
# ENVSpacingClass_AnyZoneAtInitialClass             51
# ENVSpacingClass_SameZoneAtInitialClass            51
# ENVSpacingClass_Vertical100AtInitialClass         51
# ParentChildVertical100                            51
# ParentChildAnyZoneAtInitial                       51
# ParentChildSameZoneAtInitial                      51
# ParentChildVertical100AtInitial                   51
# SpudDateSource                                     6
# TestRate_MCFEPerDAYPer1000FT                    1105
# FirstProdYear                                      0
# Avg3DDistSameZone_FT                             390
# VerticalBoundedSameZoneAtInitial                  51
# VerticalBoundedSameZoneAtCurrent                  51
# NearNeighborCountSameZone                         51
# Closest3DDistAtDrillTimeAnyZone_FT               178
# Closest3DDistAtDrillTimeSameZone_FT              610
# Avg3DDistAtDrillTimeAnyZone_FT                   178
# Avg3DDistAtDrillTimeSameZone_FT                  610
# Closest3DDistToParentAtDrillTimeAnyZone_FT      1106
# Closest3DDistToParentAtDrillTimeSameZone_FT     1941
# Avg3DDistToParentAtDrillTimeAnyZone_FT          1106
# Avg3DDistToParentAtDrillTimeSameZone_FT         1941
# ClosestHzDistToParentAtDrillTimeAnyZone_FT      1106
# ClosestHzDistToParentAtDrillTimeSameZone_FT     1941
# AvgHzDistToParentAtDrillTimeAnyZone_FT          1106
# AvgHzDistToParentAtDrillTimeSameZone_FT         1941
# ClosestVtDistToParentAtDrillTimeAnyZone_FT      1106
# ClosestVtDistToParentAtDrillTimeSameZone_FT     1941
# AvgVtDistToParentAtDrillTimeAnyZone_FT          1106
# AvgVtDistToParentAtDrillTimeSameZone_FT         1941
# ParentWellCountAtDrillTimeAnyZone                 51
# ParentWellCountAtDrillTimeSameZone                51
# VerticalBoundedAtDrillTimeAnyZone                 51
# NearNeighborCountAtDrillTimeAnyZone               51
# NearNeighborCountAtDrillTimeSameZone              51
# Closest3DDistAnyZone_FT                           86
# Closest3DDistSameZone_FT                         390
# Avg3DDistAnyZone_FT                               86
# VerticalBoundedAnyZone                            51
# NearNeighborCountAnyZone                          51
# Closest3DDistAtDrillTime100dVZone_FT             444
# Avg3DDistAtDrillTime100dVZone_FT                 444
# Closest3DDistToParentAtDrillTime100dVZone_FT    1788
# Avg3DDistToParentAtDrillTime100dVZone_FT        1788
# ClosestHzDistToParentAtDrillTime100dVZone_FT    1788
# AvgHzDistToParentAtDrillTime100dVZone_FT        1788
# ParentWellCountAtDrillTime100dVZone               51
# NearNeighborCountAtDrillTime100dVZone             51
# Closest3DDist100dVZone_FT                        236
# Avg3DDist100dVZone_FT                            236
# NearNeighborCount100dVZone                        51
# ClosestVtDistToParentAtDrillTime100dVZone_FT    1447
# AvgVtDistToParentAtDrillTime100dVZone_FT        1447
# VerticalBoundedAtDrillTime100dVZone               51
# VerticalBounded100dVZone                          51
# VerticalParentChildAtDrillTimeSameZone            51
# EnvVerticalSpacingClassAtDrillTimeSameZone        51
# VerticalParentChildSameZone                       51
# EnvVerticalSpacingClassSameZone                   51
# VerticalParentChildAtDrillTimeAnyZone             51
# EnvVerticalSpacingClassAtDrillTimeAnyZone         51
# VerticalParentChildAnyZone                        51
# EnvVerticalSpacingClassAnyZone                    51
# VerticalParentChildAtDrillTime100dVZone           51
# EnvVerticalSpacingClassAtDrillTime100dVZone       51
# VerticalParentChild100dVZone                      51
# EnvVerticalSpacingClass100dVZone                  51
# EURWH_MBOEPer1000FT                              155
# EURWH_MBOE_60Per1000FT                           155
# EURWH_MBOE_120Per1000FT                          155
# EURWH_MBOE_180Per1000FT                          155
# EURWH_MBOE_360PEr1000FT                          155
# EURWH_BCFE_360Per1000FT                          155
# OilEURWH_MBBLPer1000FT                           155
# EURWH_MBBL_360Per1000FT                          155
# GasEURWH_BCFPer1000FT                            155
# EURWH_BCF_360Per1000FT                           155
# EURPP_MBOEPer1000FT                              178
# dtype: int64

# %%
columns_to_retain = [
    'API_UWI',
    'County',
    'CumProd_BOEPer1000FT',
    'CumGas_MCFPer1000FT',
    'CumProd_MCFEPer1000FT',
    'CumOil_BBLPer1000FT',
    'TotalProducingMonths',
    'Isopach_FT',
    'GammaRay_API',
    'BulkDensity_GPerCC',
    'Resistivity_OHMSM',
    'DensityPorosity_PCT',
    'EffectivePorosity_PCT',
    'ClayVolume_PCT',
    'NonClayVolume_PCT',
    'WaterSaturation_PCT',
    'PhiH_FT',
    'HCPV_PCT',
    'HeightOfHCPV_FT'
]
# Retain only the specified columns
metadata_df = metadata_df[columns_to_retain]

# %%
metadata_df.columns
# Out:
# Index(['API_UWI', 'County', 'CumProd_BOEPer1000FT', 'CumGas_MCFPer1000FT',
#        'CumProd_MCFEPer1000FT', 'CumOil_BBLPer1000FT', 'TotalProducingMonths',
#        'Isopach_FT', 'GammaRay_API', 'BulkDensity_GPerCC', 'Resistivity_OHMSM',
#        'DensityPorosity_PCT', 'EffectivePorosity_PCT', 'ClayVolume_PCT',
#        'NonClayVolume_PCT', 'WaterSaturation_PCT', 'PhiH_FT', 'HCPV_PCT',
#        'HeightOfHCPV_FT'],
#       dtype='object')

# %%
metadata_df.head()
# Out:
#         API_UWI County  CumProd_BOEPer1000FT  CumGas_MCFPer1000FT  \
# 0  30-015-43706   EDDY              107992.0             260983.0
# 1  30-025-44687    LEA               40591.0              52637.0
# 2  30-025-46812    LEA               49143.0              50224.0
# 3  30-025-44013    LEA               64979.0              95748.0
# 4  30-015-49326   EDDY               50108.0             122893.0
#
#    CumProd_MCFEPer1000FT  CumOil_BBLPer1000FT  TotalProducingMonths  \
# 0               647951.0              64495.0                  84.0
# 1               243544.0              31818.0                  47.0
# 2               294856.0              40772.0                  34.0
# 3               389875.0              49021.0                  68.0
# 4               300646.0              29625.0                  13.0
#
#    Isopach_FT  GammaRay_API  BulkDensity_GPerCC  Resistivity_OHMSM  \
# 0       220.0         61.08                2.60              94.67
# 1       151.0         70.40                2.55             174.31
# 2       309.0         74.89                2.56              90.51
# 3        85.0         73.86                2.56              91.03
# 4       216.0         81.37                2.59             181.22
#
#    DensityPorosity_PCT  EffectivePorosity_PCT  ClayVolume_PCT  \
# 0                0.064                  0.055            0.15
# 1                0.093                  0.075            0.16
# 2                0.080                  0.061            0.21
# 3                0.088                  0.073            0.17
# 4                0.073                  0.060            0.20
#
#    NonClayVolume_PCT  WaterSaturation_PCT  PhiH_FT  HCPV_PCT  HeightOfHCPV_FT
# 0               0.80                 0.52    12.17     0.029              6.5
# 1               0.76                 0.39    11.33     0.043              6.6
# 2               0.72                 0.46    18.81     0.032              9.9
# 3               0.76                 0.59     6.20     0.031              2.6
# 4               0.73                 0.41    12.87     0.035              7.6

# %%
plt.figure(figsize=(10, 6))
plt.scatter( metadata_df['DensityPorosity_PCT'],metadata_df['CumProd_BOEPer1000FT'], alpha=0.5)
plt.title('Distribution of Density Porosity vs Cumulative Production')
plt.xlabel('Density Porosity (%)')
plt.ylabel('Cumulative Production (BOE/1000FT)')
plt.grid(True)
plt.show()


plt.figure(figsize=(10, 6))
plt.hist(metadata_df['DensityPorosity_PCT'], bins=20, density=True, alpha=0.7)
plt.title('DensityPorosity_PCT Distribution')
plt.xlabel('Density Porosity (%)')
plt.ylabel('Density')
plt.grid(True)
plt.show()


peak_density_porosity = metadata_df['DensityPorosity_PCT'].mode()[0]
print("Peak Density Porosity:", peak_density_porosity)


peak_range = 0.01  
peak_density_porosity_count = ((metadata_df['DensityPorosity_PCT'] >= peak_density_porosity - peak_range) & 
                               (metadata_df['DensityPorosity_PCT'] <= peak_density_porosity + peak_range)).sum()
total_count = len(metadata_df)
percentage_in_peak_range = peak_density_porosity_count / total_count * 100
print("Percentage of data within peak range:", percentage_in_peak_range)

peak_density_porosity_data = metadata_df[(metadata_df['DensityPorosity_PCT'] >= peak_density_porosity - peak_range) & 
                                         (metadata_df['DensityPorosity_PCT'] <= peak_density_porosity + peak_range)]
other_density_porosity_data = metadata_df[(metadata_df['DensityPorosity_PCT'] < peak_density_porosity - peak_range) | 
                                          (metadata_df['DensityPorosity_PCT'] > peak_density_porosity + peak_range)]

t_stat, p_value = stats.ttest_ind(peak_density_porosity_data['CumProd_BOEPer1000FT'], other_density_porosity_data['CumProd_BOEPer1000FT'])
print("t-statistic:", t_stat)
print("p-value:", p_value)
# Out:
# Peak Density Porosity: 0.08
# Percentage of data within peak range: 64.47782046804052
# t-statistic: -3.6911903810183198
# p-value: 0.00022742772301823002

# %%
variables = ['GammaRay_API', 'BulkDensity_GPerCC', 'Resistivity_OHMSM', 'DensityPorosity_PCT', 
             'EffectivePorosity_PCT', 'ClayVolume_PCT', 'NonClayVolume_PCT', 'WaterSaturation_PCT', 
             'PhiH_FT', 'HCPV_PCT', 'HeightOfHCPV_FT']

significant_columns = []

for variable in variables:
    plt.figure(figsize=(10, 6))
    plt.scatter(metadata_df[variable], metadata_df['CumProd_BOEPer1000FT'], alpha=0.5)
    plt.title(f'Distribution of {variable} vs Cumulative Production')
    plt.xlabel(variable)
    plt.ylabel('Cumulative Production (BOE/1000FT)')
    plt.grid(True)
    plt.show()

    plt.figure(figsize=(10, 6))
    plt.hist(metadata_df[variable], bins=20, density=True, alpha=0.7)
    plt.title(f'{variable} Distribution')
    plt.xlabel(variable)
    plt.ylabel('Density')
    plt.grid(True)
    plt.show()

    # 生産量のピークを特定する
    peak_variable = metadata_df[variable].mode()[0]
    peak_range = 0.01  # 0.01の範囲をピークの周りとして定義
    peak_variable_data = metadata_df[(metadata_df[variable] >= peak_variable - peak_range) & 
                                      (metadata_df[variable] <= peak_variable + peak_range)]
    other_variable_data = metadata_df[(metadata_df[variable] < peak_variable - peak_range) | 
                                       (metadata_df[variable] > peak_variable + peak_range)]

    t_stat, p_value = stats.ttest_ind(peak_variable_data['CumProd_BOEPer1000FT'], other_variable_data['CumProd_BOEPer1000FT'])
    
    if p_value < 0.05:
        significant_columns.append(variable)
        print(f"{variable} has a significant difference in cumulative production around its peak.")

print("Columns with significant differences in cumulative production:", significant_columns)
# Out:
# GammaRay_API has a significant difference in cumulative production around its peak.
# BulkDensity_GPerCC has a significant difference in cumulative production around its peak.
# DensityPorosity_PCT has a significant difference in cumulative production around its peak.
# NonClayVolume_PCT has a significant difference in cumulative production around its peak.
# Columns with significant differences in cumulative production: ['GammaRay_API', 'BulkDensity_GPerCC', 'DensityPorosity_PCT', 'NonClayVolume_PCT']

# %%
def define_features(input_features):
    """
    Define features for identifying similar wells.
    
    Args:
    - input_features (dict): Dictionary containing input features provided by the customer.
    
    Returns:
    - similar_well_features (list): List containing the selected features for identifying similar wells.
    """
    # Select the relevant features
    similar_well_features = [
        input_features['GammaRay_API'],
        input_features['BulkDensity_GPerCC'],
        input_features['DensityPorosity_PCT'],
        input_features['NonClayVolume_PCT']
    ]
    
    return similar_well_features

# %%
from scipy.spatial.distance import euclidean

def calculate_similarity(input_features, other_features):
    # Calculate Euclidean distance between input_features and other_features
    similarity = euclidean(input_features, other_features)
    return similarity

# %%
other_features_df = metadata_df[['GammaRay_API', 'BulkDensity_GPerCC', 'DensityPorosity_PCT', 'NonClayVolume_PCT']]
other_features_df.dropna(inplace=True)

# %%
# NaN値と無限大を持つ行を削除する
other_features_df = other_features_df.replace([np.inf, -np.inf], np.nan)
other_features_df = other_features_df.dropna()

# NaN値と無限大が存在するかを確認する
print(other_features_df.isin([np.inf, -np.inf]).any())
# Out:
# GammaRay_API           False
# BulkDensity_GPerCC     False
# DensityPorosity_PCT    False
# NonClayVolume_PCT      False
# dtype: bool

# %%
# CLIENTS INPUTS FOR PARAMETER OF THE WELL 
customer_input = {
    'GammaRay_API': 60.08,
    'BulkDensity_GPerCC': 1.50,
    'DensityPorosity_PCT': 0.084,
    'NonClayVolume_PCT': 0.40
}

# %%
from scipy.spatial.distance import euclidean

def calculate_similarity(input_features, other_features):
    # Calculate Euclidean distance between input_features and other_features
    similarity = euclidean(input_features, other_features)
    return similarity


# Other featuresをnumpy arrayに変換
other_features_array = other_features_df.to_numpy()

# 入力特徴量をnumpy arrayに変換
input_features_array = np.array(list(customer_input.values()))

# 類似度の計算
similarities = []
for other_feature_set in other_features_array:
    similarity = calculate_similarity(input_features_array, other_feature_set)
    similarities.append(similarity)

# 最も類似した油井を特定
most_similar_index = np.argmin(similarities)
most_similar_well = metadata_df.iloc[most_similar_index]

print("Most similar well:")
print(most_similar_well)
# Out:
# Most similar well:
# API_UWI                  30-015-48297
# County                           EDDY
# CumProd_BOEPer1000FT          47749.0
# CumGas_MCFPer1000FT          111901.0
# CumProd_MCFEPer1000FT        286495.0
# CumOil_BBLPer1000FT           29099.0
# TotalProducingMonths             15.0
# Isopach_FT                      158.0
# GammaRay_API                    55.37
# BulkDensity_GPerCC                2.6
# Resistivity_OHMSM              104.18
# DensityPorosity_PCT             0.065
# EffectivePorosity_PCT           0.055
# ClayVolume_PCT                   0.14
# NonClayVolume_PCT                 0.8
# WaterSaturation_PCT              0.56
# PhiH_FT                          8.66
# HCPV_PCT                        0.028
# HeightOfHCPV_FT                   4.4
# Name: 462, dtype: object

# %%
most_similar_well_API_UWI = most_similar_well['API_UWI']

selected_well_production = production_df[production_df['API_UWI'] == most_similar_well_API_UWI]
selected_well_production
# Out:
#             API_UWI                     WellName ProducingMonth  \
# 17459  30-015-48297  CYPRESS 33 FEDERAL COM 207H     2022-07-01
# 17460  30-015-48297  CYPRESS 33 FEDERAL COM 207H     2022-08-01
# 17461  30-015-48297  CYPRESS 33 FEDERAL COM 207H     2022-09-01
# 17462  30-015-48297  CYPRESS 33 FEDERAL COM 207H     2022-10-01
# 17463  30-015-48297  CYPRESS 33 FEDERAL COM 207H     2022-11-01
# 17464  30-015-48297  CYPRESS 33 FEDERAL COM 207H     2022-12-01
# 17465  30-015-48297  CYPRESS 33 FEDERAL COM 207H     2023-01-01
# 17466  30-015-48297  CYPRESS 33 FEDERAL COM 207H     2023-02-01
# 17467  30-015-48297  CYPRESS 33 FEDERAL COM 207H     2023-03-01
# 17468  30-015-48297  CYPRESS 33 FEDERAL COM 207H     2023-04-01
# 17469  30-015-48297  CYPRESS 33 FEDERAL COM 207H     2023-05-01
# 17470  30-015-48297  CYPRESS 33 FEDERAL COM 207H     2023-06-01
# 17471  30-015-48297  CYPRESS 33 FEDERAL COM 207H     2023-07-01
# 17472  30-015-48297  CYPRESS 33 FEDERAL COM 207H     2023-08-01
# 17473  30-015-48297  CYPRESS 33 FEDERAL COM 207H     2023-09-01
#
#        TotalProdMonths  Prod_BOE  Prod_MCFE  LiquidsProd_BBL  GasProd_MCF  \
# 17459                1       116        697               30          517
# 17460                2     34778     208670            22759        72116
# 17461                3     33661     201967            22208        68719
# 17462                4     23369     140211            12068        67803
# 17463                5     23357     140141            15309        48287
# 17464                6     22614     135685            13013        57607
# 17465                7     16143      96860            10445        34190
# 17466                8     14696      88174             9269        32560
# 17467                9     15274      91642             8921        38116
# 17468               10     12605      75631             7261        32065
# 17469               11      7056      42337             3616        20641
# 17470               12      7955      47729             4657        19787
# 17471               13      8825      52952             5074        22508
# 17472               14      7488      44929             4270        19309
# 17473               15      6893      41357             4209        16103
#
#        WaterProd_BBL  RepGasProd_MCF ProductionReportedMethod  \
# 17459           1003               0                 REPORTED
# 17460          87503               0                 REPORTED
# 17461          80921               0                 REPORTED
# 17462          49151               0                 REPORTED
# 17463          52569               0                 REPORTED
# 17464          41624               0                 REPORTED
# 17465          25603               0                 REPORTED
# 17466          33945               0                 REPORTED
# 17467          33518               0                 REPORTED
# 17468          29674               0                 REPORTED
# 17469          19893               0                 REPORTED
# 17470          20751               0                 REPORTED
# 17471          21423               0                 REPORTED
# 17472          18659               0                 REPORTED
# 17473          16226               0                 REPORTED
#
#              ProducingOperator  ENVProdID
# 17459  TAP ROCK OPERATING, LLC          1
# 17460  TAP ROCK OPERATING, LLC          1
# 17461  TAP ROCK OPERATING, LLC          1
# 17462  TAP ROCK OPERATING, LLC          1
# 17463  TAP ROCK OPERATING, LLC          1
# 17464  TAP ROCK OPERATING, LLC          1
# 17465              OXY USA INC          1
# 17466              OXY USA INC          1
# 17467              OXY USA INC          1
# 17468              OXY USA INC          1
# 17469              OXY USA INC          1
# 17470              OXY USA INC          1
# 17471              OXY USA INC          1
# 17472              OXY USA INC          1
# 17473              OXY USA INC          1

# %%
selected_well_production[['TotalProdMonths', 'Prod_BOE']]
# Out:
#        TotalProdMonths  Prod_BOE
# 17459                1       116
# 17460                2     34778
# 17461                3     33661
# 17462                4     23369
# 17463                5     23357
# 17464                6     22614
# 17465                7     16143
# 17466                8     14696
# 17467                9     15274
# 17468               10     12605
# 17469               11      7056
# 17470               12      7955
# 17471               13      8825
# 17472               14      7488
# 17473               15      6893

# %%
model = ARIMA(selected_well_production['Prod_BOE'], order=(1,1,1))
model_fit = model.fit()
aic = model_fit.aic

print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:               Prod_BOE   No. Observations:                   15
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                -148.664
# Date:                Tue, 27 Feb 2024   AIC                            303.328
# Time:                        21:57:55   BIC                            305.245
# Sample:                             0   HQIC                           303.150
#                                  - 15
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.8018      0.599     -1.339      0.181      -1.976       0.372
# ma.L1          1.0000      0.327      3.060      0.002       0.360       1.640
# sigma2      9.202e+07   3.55e-09   2.59e+16      0.000     9.2e+07     9.2e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.21   Jarque-Bera (JB):                43.63
# Prob(Q):                              0.65   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.05   Skew:                             2.72
# Prob(H) (two-sided):                  0.01   Kurtosis:                         9.73
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.09e+33. Standard errors may be unstable.

# %%
# CLIENT'S INPUTs ( Assume that they want to predict the well (Let's say Total Months: 15 months))

sample = {
    'TotalProdMonths': list(range(1, 16)),
    'Prod_BOE': [116, 34778, 33661, 23369, 23357, 22614, 16143, 14696, 15274, 12605, 7056, 7955, 8825, 7488, 6893]
}


# Create DataFrame
sample = pd.DataFrame(sample)
sample
# Out:
#     TotalProdMonths  Prod_BOE
# 0                 1       116
# 1                 2     34778
# 2                 3     33661
# 3                 4     23369
# 4                 5     23357
# 5                 6     22614
# 6                 7     16143
# 7                 8     14696
# 8                 9     15274
# 9                10     12605
# 10               11      7056
# 11               12      7955
# 12               13      8825
# 13               14      7488
# 14               15      6893

# %%
forecast = model_fit.forecast(steps=12)  


forecast_data = {
    'TotalProdMonths': list(range(15, 27)),  
    'Prod_BOE': forecast 
}
forecast_df = pd.DataFrame(forecast_data)

# 元のデータと予測データを結合
combined_df = pd.concat([sample, forecast_df])

# グラフの描画
plt.plot(sample['TotalProdMonths'], sample['Prod_BOE'], marker='o', label='Actual')
plt.plot(forecast_df['TotalProdMonths'], forecast_df['Prod_BOE'], linestyle='--', marker='o', color='red', label='Forecast')
plt.xlabel('TotalProdMonths')
plt.ylabel('Prod_BOE')
plt.title('ARIMA Forecast for Well Production')
plt.legend()
plt.show()
